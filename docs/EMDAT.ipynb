# %% [markdown]
# Import modulov

# %%
from skgaze.core.Dataset import Dataset
from skgaze.core.EMDAT import EMDAT

# %% [markdown]
# Načítanie dátovej sady

# %%
dataset = Dataset('../data/DOD2016_fixations_10_participants.tsv',
'../data/SegmentedPages.txt')

# %% [markdown]
# Vytvorenie inštancie pre participanta P01m

# %%
emdat = EMDAT(dataset,"P01m").createInstance()
# Out:
# reading the files
# Done!
# {'problem': [('Segment', 12489.0, 44305.0)]}
# partition done!
# Preparing scene:problem
#
# segid, start, end: Segment 12489.0 44305.0

# %% [markdown]
# Zavolanie funkcie getAoiData pre element header

# %%
emdat.getAoiData("header")
# Out:
# {'numfixations': 9,
#  'longestfixation': 250,
#  'timetofirstfixation': 15362.0,
#  'timetolastfixation': 26179.0,
#  'proportionnum': 0.10975609756097561,
#  'totaltimespent': 1449,
#  'proportiontime': 0.04554312295700277,
#  'fixationrate': 0.006211180124223602,
#  'numtransto_header': 0,
#  'numtransfrom_header': 0,
#  'numtransto_top-menu': 0,
#  'numtransfrom_top-menu': 0,
#  'numtransto_carousel': 0,
#  'numtransfrom_carousel': 0,
#  'numtransto_side-menu': 0,
#  'numtransfrom_side-menu': 0,
#  'numtransto_news-tp-cup': 0,
#  'numtransfrom_news-tp-cup': 0,
#  'numtransto_news-dod': 0,
#  'numtransfrom_news-dod': 0,
#  'numtransto_down-news': 0,
#  'numtransfrom_down-news': 0,
#  'numtransto_about-fiit': 0,
#  'numtransfrom_about-fiit': 0,
#  'numtransto_contacts': 0,
#  'numtransfrom_contacts': 0,
#  'numtransto_map-location': 0,
#  'numtransfrom_map-location': 0,
#  'numtransto_logos-and-social': 0,
#  'numtransfrom_logos-and-social': 0,
#  'numtransto_down-menu': 0,
#  'numtransfrom_down-menu': 0,
#  'numtransto_footer': 0,
#  'numtransfrom_footer': 0,
#  'numtransto_header-links': 0,
#  'numtransfrom_header-links': 0,
#  'numtransto_header-search': 0,
#  'numtransfrom_header-search': 0,
#  'numtransto_header-logo': 0,
#  'numtransfrom_header-logo': 0,
#  'numtransto_top-menu-faculty': 0,
#  'numtransfrom_top-menu-faculty': 0,
#  'numtransto_top-menu-prospective-students': 0,
#  'numtransfrom_top-menu-prospective-students': 0,
#  'numtransto_top-menu-students': 0,
#  'numtransfrom_top-menu-students': 0,
#  'numtransto_top-menu-alumni': 0,
#  'numtransfrom_top-menu-alumni': 0,
#  'numtransto_top-menu-research': 0,
#  'numtransfrom_top-menu-research': 0,
#  'numtransto_top-menu-public': 0,
#  'numtransfrom_top-menu-public': 0,
#  'numtransto_top-menu-employees': 0,
#  'numtransfrom_top-menu-employees': 0,
#  'numtransto_down-menu-study': 0,
#  'numtransfrom_down-menu-study': 0,
#  'numtransto_down-menu-research': 0,
#  'numtransfrom_down-menu-research': 0,
#  'numtransto_down-menu-international': 0,
#  'numtransfrom_down-menu-international': 0,
#  'numtransto_down-menu-faculty': 0,
#  'numtransfrom_down-menu-faculty': 0,
#  'numtransto_down-menu-media': 0,
#  'numtransfrom_down-menu-media': 0,
#  'numtransto_down-menu-links': 0,
#  'numtransfrom_down-menu-links': 0,
#  'numtransto_down-menu-accessiblity': 0,
#  'numtransfrom_down-menu-accessiblity': 0,
#  'numtransto_main-body': 0,
#  'numtransfrom_main-body': 0,
#  'numtransto_Rectangle': 0,
#  'numtransfrom_Rectangle': 0,
#  'numtransto_Polygon': 0,
#  'numtransfrom_Polygon': 0,
#  'proptransto_header': 0,
#  'proptransfrom_header': 0,
#  'proptransto_top-menu': 0,
#  'proptransfrom_top-menu': 0,
#  'proptransto_carousel': 0,
#  'proptransfrom_carousel': 0,
#  'proptransto_side-menu': 0,
#  'proptransfrom_side-menu': 0,
#  'proptransto_news-tp-cup': 0,
#  'proptransfrom_news-tp-cup': 0,
#  'proptransto_news-dod': 0,
#  'proptransfrom_news-dod': 0,
#  'proptransto_down-news': 0,
#  'proptransfrom_down-news': 0,
#  'proptransto_about-fiit': 0,
#  'proptransfrom_about-fiit': 0,
#  'proptransto_contacts': 0,
#  'proptransfrom_contacts': 0,
#  'proptransto_map-location': 0,
#  'proptransfrom_map-location': 0,
#  'proptransto_logos-and-social': 0,
#  'proptransfrom_logos-and-social': 0,
#  'proptransto_down-menu': 0,
#  'proptransfrom_down-menu': 0,
#  'proptransto_footer': 0,
#  'proptransfrom_footer': 0,
#  'proptransto_header-links': 0,
#  'proptransfrom_header-links': 0,
#  'proptransto_header-search': 0,
#  'proptransfrom_header-search': 0,
#  'proptransto_header-logo': 0,
#  'proptransfrom_header-logo': 0,
#  'proptransto_top-menu-faculty': 0,
#  'proptransfrom_top-menu-faculty': 0,
#  'proptransto_top-menu-prospective-students': 0,
#  'proptransfrom_top-menu-prospective-students': 0,
#  'proptransto_top-menu-students': 0,
#  'proptransfrom_top-menu-students': 0,
#  'proptransto_top-menu-alumni': 0,
#  'proptransfrom_top-menu-alumni': 0,
#  'proptransto_top-menu-research': 0,
#  'proptransfrom_top-menu-research': 0,
#  'proptransto_top-menu-public': 0,
#  'proptransfrom_top-menu-public': 0,
#  'proptransto_top-menu-employees': 0,
#  'proptransfrom_top-menu-employees': 0,
#  'proptransto_down-menu-study': 0,
#  'proptransfrom_down-menu-study': 0,
#  'proptransto_down-menu-research': 0,
#  'proptransfrom_down-menu-research': 0,
#  'proptransto_down-menu-international': 0,
#  'proptransfrom_down-menu-international': 0,
#  'proptransto_down-menu-faculty': 0,
#  'proptransfrom_down-menu-faculty': 0,
#  'proptransto_down-menu-media': 0,
#  'proptransfrom_down-menu-media': 0,
#  'proptransto_down-menu-links': 0,
#  'proptransfrom_down-menu-links': 0,
#  'proptransto_down-menu-accessiblity': 0,
#  'proptransfrom_down-menu-accessiblity': 0,
#  'proptransto_main-body': 0,
#  'proptransfrom_main-body': 0,
#  'proptransto_Rectangle': 0,
#  'proptransfrom_Rectangle': 0,
#  'proptransto_Polygon': 0,
#  'proptransfrom_Polygon': 0}

# %% [markdown]
# Vytvorenie inštancie triedy EMDAT pre všetkých participantov

# %%
emdat2 = EMDAT(dataset).createInstance()
# Out:
# reading the files
# Done!
# {'problem': [('Segment', 12489.0, 44305.0)]}
# partition done!
# Preparing scene:problem
#
# segid, start, end: Segment 12489.0 44305.0
#
# reading the files
# Done!
# {'problem': [('Segment', 33910.0, 44480.0)]}
# partition done!
# Preparing scene:problem
#
# segid, start, end: Segment 33910.0 44480.0
#
# reading the files
# Done!
# {'problem': [('Segment', 11830.0, 56054.0)]}
# partition done!
# Preparing scene:problem
#
# segid, start, end: Segment 11830.0 56054.0
#
# reading the files
# Done!
# {'problem': [('Segment', 26895.0, 38538.0)]}
# partition done!
# Preparing scene:problem
#
# segid, start, end: Segment 26895.0 38538.0
#
# reading the files
# Done!
# {'problem': [('Segment', 13118.0, 23522.0)]}
# partition done!
# Preparing scene:problem
#
# segid, start, end: Segment 13118.0 23522.0
#
# reading the files
# Done!
# {'problem': [('Segment', 33406.0, 42227.0)]}
# partition done!
# Preparing scene:problem
#
# segid, start, end: Segment 33406.0 42227.0
#
# reading the files
# Done!
# {'problem': [('Segment', 18734.0, 33563.0)]}
# partition done!
# Preparing scene:problem
#
# segid, start, end: Segment 18734.0 33563.0
#
# reading the files
# Done!
# {'problem': [('Segment', 4736.0, 66209.0)]}
# partition done!
# Preparing scene:problem
#
# segid, start, end: Segment 4736.0 66209.0
#
# reading the files
# Done!
# {'problem': [('Segment', 5511.0, 16532.0)]}
# partition done!
# Preparing scene:problem
#
# segid, start, end: Segment 5511.0 16532.0
#
# reading the files
# Done!
# {'problem': [('Segment', 29149.0, 37341.0)]}
# partition done!
# Preparing scene:problem
#
# segid, start, end: Segment 29149.0 37341.0

# %% [markdown]
# Výstup volania

# %%
emdat2
# Out:
# {'P01m': <skgaze.EMDAT.BasicParticipant.BasicParticipant at 0x60e4630>,
#  'P01o': <skgaze.EMDAT.BasicParticipant.BasicParticipant at 0x6154c18>,
#  'P01n': <skgaze.EMDAT.BasicParticipant.BasicParticipant at 0x60e9160>,
#  'P01p': <skgaze.EMDAT.BasicParticipant.BasicParticipant at 0x643d048>,
#  'P01q': <skgaze.EMDAT.BasicParticipant.BasicParticipant at 0x61589e8>,
#  'P02q': <skgaze.EMDAT.BasicParticipant.BasicParticipant at 0x60e93c8>,
#  'P01r': <skgaze.EMDAT.BasicParticipant.BasicParticipant at 0x60e9470>,
#  'P03r': <skgaze.EMDAT.BasicParticipant.BasicParticipant at 0x6704550>,
#  'P01i': <skgaze.EMDAT.BasicParticipant.BasicParticipant at 0x69d4390>,
#  'P02i': <skgaze.EMDAT.BasicParticipant.BasicParticipant at 0x69dc198>}

# %% [markdown]
# Opäť možnosť volať metódu getAoiData nad konkrétnym participantom

# %%
emdat2["P01p"].getAoiData("header")
# Out:
# {'numfixations': 3,
#  'longestfixation': 217,
#  'timetofirstfixation': 3756.0,
#  'timetolastfixation': 4441.0,
#  'proportionnum': 0.07894736842105263,
#  'totaltimespent': 434,
#  'proportiontime': 0.03727561625010736,
#  'fixationrate': 0.0069124423963133645,
#  'numtransto_header': 0,
#  'numtransfrom_header': 0,
#  'numtransto_top-menu': 0,
#  'numtransfrom_top-menu': 0,
#  'numtransto_carousel': 0,
#  'numtransfrom_carousel': 0,
#  'numtransto_side-menu': 0,
#  'numtransfrom_side-menu': 0,
#  'numtransto_news-tp-cup': 0,
#  'numtransfrom_news-tp-cup': 0,
#  'numtransto_news-dod': 0,
#  'numtransfrom_news-dod': 0,
#  'numtransto_down-news': 0,
#  'numtransfrom_down-news': 0,
#  'numtransto_about-fiit': 0,
#  'numtransfrom_about-fiit': 0,
#  'numtransto_contacts': 0,
#  'numtransfrom_contacts': 0,
#  'numtransto_map-location': 0,
#  'numtransfrom_map-location': 0,
#  'numtransto_logos-and-social': 0,
#  'numtransfrom_logos-and-social': 0,
#  'numtransto_down-menu': 0,
#  'numtransfrom_down-menu': 0,
#  'numtransto_footer': 0,
#  'numtransfrom_footer': 0,
#  'numtransto_header-links': 0,
#  'numtransfrom_header-links': 0,
#  'numtransto_header-search': 0,
#  'numtransfrom_header-search': 0,
#  'numtransto_header-logo': 0,
#  'numtransfrom_header-logo': 0,
#  'numtransto_top-menu-faculty': 0,
#  'numtransfrom_top-menu-faculty': 0,
#  'numtransto_top-menu-prospective-students': 0,
#  'numtransfrom_top-menu-prospective-students': 0,
#  'numtransto_top-menu-students': 0,
#  'numtransfrom_top-menu-students': 0,
#  'numtransto_top-menu-alumni': 0,
#  'numtransfrom_top-menu-alumni': 0,
#  'numtransto_top-menu-research': 0,
#  'numtransfrom_top-menu-research': 0,
#  'numtransto_top-menu-public': 0,
#  'numtransfrom_top-menu-public': 0,
#  'numtransto_top-menu-employees': 0,
#  'numtransfrom_top-menu-employees': 0,
#  'numtransto_down-menu-study': 0,
#  'numtransfrom_down-menu-study': 0,
#  'numtransto_down-menu-research': 0,
#  'numtransfrom_down-menu-research': 0,
#  'numtransto_down-menu-international': 0,
#  'numtransfrom_down-menu-international': 0,
#  'numtransto_down-menu-faculty': 0,
#  'numtransfrom_down-menu-faculty': 0,
#  'numtransto_down-menu-media': 0,
#  'numtransfrom_down-menu-media': 0,
#  'numtransto_down-menu-links': 0,
#  'numtransfrom_down-menu-links': 0,
#  'numtransto_down-menu-accessiblity': 0,
#  'numtransfrom_down-menu-accessiblity': 0,
#  'numtransto_main-body': 0,
#  'numtransfrom_main-body': 0,
#  'numtransto_Rectangle': 0,
#  'numtransfrom_Rectangle': 0,
#  'numtransto_Polygon': 0,
#  'numtransfrom_Polygon': 0,
#  'proptransto_header': 0,
#  'proptransfrom_header': 0,
#  'proptransto_top-menu': 0,
#  'proptransfrom_top-menu': 0,
#  'proptransto_carousel': 0,
#  'proptransfrom_carousel': 0,
#  'proptransto_side-menu': 0,
#  'proptransfrom_side-menu': 0,
#  'proptransto_news-tp-cup': 0,
#  'proptransfrom_news-tp-cup': 0,
#  'proptransto_news-dod': 0,
#  'proptransfrom_news-dod': 0,
#  'proptransto_down-news': 0,
#  'proptransfrom_down-news': 0,
#  'proptransto_about-fiit': 0,
#  'proptransfrom_about-fiit': 0,
#  'proptransto_contacts': 0,
#  'proptransfrom_contacts': 0,
#  'proptransto_map-location': 0,
#  'proptransfrom_map-location': 0,
#  'proptransto_logos-and-social': 0,
#  'proptransfrom_logos-and-social': 0,
#  'proptransto_down-menu': 0,
#  'proptransfrom_down-menu': 0,
#  'proptransto_footer': 0,
#  'proptransfrom_footer': 0,
#  'proptransto_header-links': 0,
#  'proptransfrom_header-links': 0,
#  'proptransto_header-search': 0,
#  'proptransfrom_header-search': 0,
#  'proptransto_header-logo': 0,
#  'proptransfrom_header-logo': 0,
#  'proptransto_top-menu-faculty': 0,
#  'proptransfrom_top-menu-faculty': 0,
#  'proptransto_top-menu-prospective-students': 0,
#  'proptransfrom_top-menu-prospective-students': 0,
#  'proptransto_top-menu-students': 0,
#  'proptransfrom_top-menu-students': 0,
#  'proptransto_top-menu-alumni': 0,
#  'proptransfrom_top-menu-alumni': 0,
#  'proptransto_top-menu-research': 0,
#  'proptransfrom_top-menu-research': 0,
#  'proptransto_top-menu-public': 0,
#  'proptransfrom_top-menu-public': 0,
#  'proptransto_top-menu-employees': 0,
#  'proptransfrom_top-menu-employees': 0,
#  'proptransto_down-menu-study': 0,
#  'proptransfrom_down-menu-study': 0,
#  'proptransto_down-menu-research': 0,
#  'proptransfrom_down-menu-research': 0,
#  'proptransto_down-menu-international': 0,
#  'proptransfrom_down-menu-international': 0,
#  'proptransto_down-menu-faculty': 0,
#  'proptransfrom_down-menu-faculty': 0,
#  'proptransto_down-menu-media': 0,
#  'proptransfrom_down-menu-media': 0,
#  'proptransto_down-menu-links': 0,
#  'proptransfrom_down-menu-links': 0,
#  'proptransto_down-menu-accessiblity': 0,
#  'proptransfrom_down-menu-accessiblity': 0,
#  'proptransto_main-body': 0,
#  'proptransfrom_main-body': 0,
#  'proptransto_Rectangle': 0,
#  'proptransfrom_Rectangle': 0,
#  'proptransto_Polygon': 0,
#  'proptransfrom_Polygon': 0}
